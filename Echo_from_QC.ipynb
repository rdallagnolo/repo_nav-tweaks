# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

os.chdir('R:/Projects/2020081/Navigation/Water_Bottom_Picks_from_QC')

# %%
ls

# %%
seq = input("Enter 3 digit sequence number: ")

path = 'R:/Projects/2020081/Navigation/Water_Bottom_Picks_from_QC'
dirList = os.listdir(path)
for filename in dirList:
    if (filename[4:7] == seq) & (filename[16:] == 'txt'):
        line = str(filename)
        print(line)
# Out:
# seq0253_w_depth.txt

# %%
line
# Out:
# 'seq0253_w_depth.txt'

# %%
os.chdir('R:/Projects/2020081/Navigation/Water_Bottom_Picks_from_QC')
my_file = open(line)
#my_file.seek(0)
#my_file.readlines(0)
#my_file.close()

# %%
os.chdir('R:/Projects/2020081/Navigation/Water_Bottom_Picks_from_QC')
with open('teste.txt', "r") as f:
        rows = f.readlines()[2:]

# %%
rows
# Out:
# ['969\t3236.250000\t\n',
#  '970\t3236.250000\t\n',
#  '971\t3237.750000\t\n',
#  '972\t3237.750000\t\n',
#  '973\t3237.750000\t\n',
#  '974\t3239.250000\t\n',
#  '975\t3240.750000\t\n',
#  '976\t3240.750000\t\n',
#  '977\t3242.250000\t\n',
#  '978\t3242.250000\t\n',
#  '979\t3243.750000\t\n',
#  '980\t3243.750000']

# %%
import pandas as pd

# %%
df = pd.DataFrame(rows)

# %%
df.to_csv('filename.csv', index=False)

# %%
plt.plot(df[0],df[1])
plt.show()

# %%
ls

# %%
os.chdir('R:/Projects/2020081/Navigation/Geospeedometer_Speed_Tension')

# %%
ls

# %%
os.chdir('R:/Projects/2020081/Navigation/Geospeedometer_Speed_Tension')

# %%
seq = input("Enter 3 digit sequence number: ")

path = 'R:/Projects/2020081/Navigation/Geospeedometer_Speed_Tension'
dirList = os.listdir(path)
for filename in dirList:
    if (filename[11:14] == seq) & (filename[36:] == 'csv'):
        line = str(filename)
        #print(filename)

# %%
print(line)

# %%
type(line)

# %%
import matplotlib.pyplot as plt
os.chdir('R:/Projects/2020081/Navigation/Water_Bottom_Picks_from_QC')

# %%
df = pd.read_csv('seq0288_w_depth.csv',header=None)

# %%
df.describe()
# Out:
#                  0            1
# count  5113.000000  5113.000000
# mean   3525.000000  2885.477948
# std    1476.140294   212.877991
# min     969.000000  2532.750000
# 25%    2247.000000  2666.250000
# 50%    3525.000000  2882.250000
# 75%    4803.000000  3119.250000
# max    6081.000000  3156.750000

# %%
fig = plt.figure(dpi=100,figsize=[15,4.8])
axes = fig.add_axes([0,0,1,1])
axes.grid()
axes.plot(df[0],df[1])
axes.set_xlabel('Shot Point (n)')
axes.set_ylabel('Depth (m)')

plt.show()

# %%
df[0]
# Out:
# 0        969
# 1        970
# 2        971
# 3        972
# 4        973
#         ...
# 5108    6077
# 5109    6078
# 5110    6079
# 5111    6080
# 5112    6081
# Name: 0, Length: 5113, dtype: int64
